# %% [markdown]
# # Performing parameter scans using UETOOLS
#
# One typical application of UEDGE is to perform a sensitivity analysis of the solution by scanning different UEDGE variables, which can later be analyzed, as explained in Chapter 6. This Chapter will discuss some of the ways to automatically perform automated parameter scans in UEDGE.
#
# ## TOC:
# * [Parameter scans using the time-dependent solver](#dt-scan)
# * [Parameter scans using the continuation solver](#continuation-scan)

# %%
# Restore the case
from os import chdir
chdir('testcase_lores')
from uetools import Case
c = Case('input.yaml') # Create a test at variable "c" from the YAML input file
# Out:
# UEDGE configuration file /Users/holm10/.uetoolsrc read.
# Saved solution successfully restored from nc20.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.54e+00

# %% [markdown]
# ## Parameter scans using the time-dependent solver<a class="anchor" id="dt-scan"></a>
#
# The most straightforward way to perform a parameter scan is to run a series of consequtive time-dependent runs, where the variable being scanned is changed in equidistant steps. The function Case.conv_step can be used for automating this task, whenever you need to scan a single variable:

# %%
help(c.conv_step)
# Out:
# Help on method conv_step in module uetools.UeUtils.ConvergeStep:
#
# conv_step(increment, name, var, ivar=None, stop=None, inversestep=False, **kwargs) method of uetools.UeCase.Case.Case instance

# %% [markdown]
# Case.conv_step requires the increment of changed, a name for the the run series that is used to identify the resulting saves, and the parameter name for the variable to be scanned. In case of a multi-dimensional array the kwarg ivar, which is the variable index to be modified. The kwarg "stop" is used to define the stopping point of the simulation. The boolean kwarg "inversestep" is a special case used when converging the magnetic drift contribution, as the drift strength is defined as 1/b0. Setting inversestep=True takes steps in inverse parameter space, e.g. the steps are equidistant in 1/var rather than var. Additional kwargs are passed to the time-dependent solver.
#
# There are a number of pre-defined conv_step derivatives, that can be used to scan one of the most common variabels, ncore, igaso, and b0.

# %%
for func in dir(c):
    if 'conv_step_' in func: print(func)
# Out:
# conv_step_b0
# conv_step_igaso
# conv_step_ncore

# %% [markdown]
# Here, we demonstrate a short parameter scan of the core density, which is the core boundary condition in the example simulation:

# %%
c.conv_step_ncore(-1e18, 'ncore_down', iisp=0, stop=15e18, dtreal=1e-6)
# Out:
# ======================================
# Solving for ncore[0]=1.90E+19
# ======================================
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
# Requested save-path ../solutions not found, writing to cwd!
#
#  Initial successful time-step exists
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-06 ***
# ---------------------------------------------------------------
#  iter=    0 fnrm=     0.1414213847911110     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1798415728504007E-02 nfe=      3
#  iter=    2 fnrm=     0.3828659682065274E-06 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8501743664734600E-01 nfe=      1
#  iter=    1 fnrm=     0.7639425146570495E-04 nfe=      4
#  iter=    2 fnrm=     0.7262698312372630E-08 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.900e+19_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8218513764414591E-01 nfe=      1
#  iter=    1 fnrm=     0.5030177157541117E-04 nfe=      4
#  iter=    2 fnrm=     0.1760956173079398E-08 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.900e+19_last_ii2.hdf5
#  Total time = 1.0000E-06; Timestep = 1.0000E-06
#
#  Inner iteration #2
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.7961969897845389E-01 nfe=      1
#  iter=    1 fnrm=     0.3696859063153030E-04 nfe=      4
#  iter=    2 fnrm=     0.1598543016933231E-08 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.900e+19_last_ii2.hdf5
#  Total time = 2.0000E-06; Timestep = 1.0000E-06
#
#  Inner iteration #3
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.
#
#  Inner iteration #3
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.6359460294726474E-03 nfe=      1
#  iter=    1 fnrm=     0.2790749618496386E-04 nfe=     11
#  iter=    2 fnrm=     0.1450049175835995E-09 nfe=     22
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 4.8222E-02; Timestep = 8.6653E-03
#
#  Inner iteration #4
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4413092529903437E-03 nfe=      1
#  iter=    1 fnrm=     0.8125153804724976E-05 nfe=     12
#  iter=    2 fnrm=     0.1744820759019809E-10 nfe=     24
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 5.6888E-02; Timestep = 8.6653E-03
#
#  Inner iteration #5
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3494750491861740E-03 nfe=      1
#  iter=    1 fnrm=     0.2477582692755700E-05 nfe=     12
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 6.5553E-02; Timestep = 8.6653E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 19 New time-step: 2.95E-02 ***
# ----------------------------------------------------------------
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.2904810146039283E-03 nfe=      1
#  iter=    1 fnrm=     0.3372553060648190E-05 nfe=     13
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1610802507115894E-03 nfe=      1
#  iter=    1 fnrm=     0.7093020856238180E-06 nfe=     13
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 1.0368E-01; Timestep = 2.9462E-02
#
#  Inner iteration #2
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8428982400501357E-04 nfe=      1
#  iter=    1 fnrm=     0.1585959291469501E-06 nfe=     14
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 1.3314E-01; Timestep = 2.9462E-02
#
#  Inner iteration #3
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4185975425959826E-04 nfe=      1
#  iter=    1 fnrm=     0.3471754892684169E-07 nfe=     14
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 1.6260E-01; Timestep = 2.9462E-02
#
#  Inner iteration #4
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.2010459125952087E-04 nfe=      1
#  iter=    1 fnrm=     0.7495168362491923E-08 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 1.9207E-01; Timestep = 2.9462E-02
#
#  Inner iteration #5
#
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Reading grid data from gridue.hdf5.hdf5
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.9457323084364390E-05 nfe=      1
#  iter=    1 fnrm=     0.1623526003955046E-08 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 2.2153E-01; Timestep = 2.9462E-02
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 20 New time-step: 1.00E-01 ***
# ----------------------------------------------------------------
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4426236957485939E-05 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.7520704677130356E-09 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8858022868902932E-06 nfe=      1
#  iter=    1 fnrm=     0.4494032177845311E-10 nfe=     16
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 3.5116E-01; Timestep = 1.0017E-01
#
#  Inner iteration #2
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1760378201897969E-06 nfe=      1
#  iter=    1 fnrm=     0.1308571274315280E-10 nfe=     17
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 4.5133E-01; Timestep = 1.0017E-01
#
#  Inner iteration #3
#
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Reading grid data from gridue.hdf5.hdf5
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3483968955116038E-07 nfe=      1
#  iter=    1 fnrm=     0.2296518649919991E-11 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 5.5150E-01; Timestep = 1.0017E-01
#
#  Inner iteration #4
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.6880620993644969E-08 nfe=      1
#  iter=    1 fnrm=     0.4936381710220256E-12 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#  Total time = 6.5167E-01; Timestep = 1.0017E-01
#
#  Inner iteration #5
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1357421314212293E-08 nfe=      1
#  iter=    1 fnrm=     0.2434325688474858E-12 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down_ncore=1.400e+19_last_ii2.hdf5
#
# ******************************
# ** SUCCESS: fnrm < bbb.ftol **
# ******************************
# Total runtime: 0:00:38

# %% [markdown]
# Once ncore has reached the defined stopping threshold, a collection of saves have been created, spanning the parameter scan, which can be utilized in databases as discussed in Chapter 6.

# %%
# !ls -h ncore_down*.hdf5
# Out:
# ncore_down_ncore=1.400e+19_last_ii2.hdf5
# ncore_down_ncore=1.500e+19_last_ii2.hdf5
# ncore_down_ncore=1.600e+19_last_ii2.hdf5
# ncore_down_ncore=1.700e+19_last_ii2.hdf5
# ncore_down_ncore=1.800e+19_last_ii2.hdf5
# ncore_down_ncore=1.900e+19_last_ii2.hdf5

# %% [markdown]
# ## Parameter scans using the continuation solver<a class="anchor" id="continuation-scan"></a>
# As mentioned in Chapter 4, the continuation solver is an ideal tool for performing parameter scans, as each successful solver step produces a converged solution, contrary to the time-dependent solver. Additionally, the continuation solver can perform a parameter scan in several dimensions. Note that each of the varied variables are evolved linearly and in an equal fraction of the difference from the starting point to the target.
#
# The frequency with which saves are written to the run-folder by the continuation solver is controlled by the variable saveres. Saveres defaults to 7, which means every 7th successful solver step is stored. The variable increments can, however, not be controlled in the continuation solver, as the algorithm tries to maximize the increments between solutions.

# %%
c.continuation_solve('ncore', target=10e18, savedir='ncore_down', index=0)
# Out:
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
# ===== MAIN LOOP 1/7 ===== iter=    0 fnrm=     0.8081220356416489E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2080598497145761E-05 nfe=     13
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3369584256180797E-04 nfe=      1
#  iter=    1 fnrm=     0.1128924211301186E-06 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ncore_down/progress0p001.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.100%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    999
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8081538853364534E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.200%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    998
#
#  iter=    1 fnrm=     0.2151677321746652E-05 nfe=     13
#  iter=    2 fnrm=     0.6256524595709534E-11 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8088349696615745E-03 nfe=      1
#  iter=    1 fnrm=     0.2527333123372038E-05 nfe=     13
#  iter=    2 fnrm=     0.1020484721494436E-10 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.300%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    997
#
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8089789507286928E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.400%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    996
#
#  iter=    1 fnrm=     0.2641082757792348E-05 nfe=     13
#  iter=    2 fnrm=     0.1159407651487151E-10 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8090097438811577E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.2699567026063448E-05 nfe=     13
#  iter=    2 fnrm=     0.1231282716293612E-10 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.500%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    995
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8090286070465404E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.600%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    994
#
#  iter=    1 fnrm=     0.2739573329176961E-05 nfe=     13
#  iter=    2 fnrm=     0.1307009755814281E-10 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8090426005074782E-03 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.700%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    451
#
#  iter=    1 fnrm=     0.5512360880127999E-05 nfe=     13
#  iter=    2 fnrm=     0.1873454016145657E-10 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.1781856412938556E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1183571764693754E-04 nfe=     10
#  iter=    2 fnrm=     0.2485618794718330E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             0.920%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    450
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1783163589650776E-02 nfe=      1
#  iter=    1 fnrm=     0.1339208091473599E-04 nfe=     10
#  iter=    2 fnrm=     0.3537806168994131E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ncore_down/progress0p011.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             1.140%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    449
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1783361265699410E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             1.360%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    448
#
#  iter=    1 fnrm=     0.1403691260432388E-04 nfe=     10
#  iter=    2 fnrm=     0.4087135052501076E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1783405224565283E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             1.580%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    447
#
#  iter=    1 fnrm=     0.1449415481069745E-04 nfe=     10
#  iter=    2 fnrm=     0.4525435442142436E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1783432752002809E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             1.800%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    446
#
#  iter=    1 fnrm=     0.1489705359347525E-04 nfe=     10
#  iter=    2 fnrm=     0.4950803599539748E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.1783452487579198E-02 nfe=      1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             2.020%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    445
#
#  iter=    1 fnrm=     0.1566076442045443E-04 nfe=     10
#  iter=    2 fnrm=     0.5427717069390422E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1783465046012605E-02 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             2.240%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    201
#
#  iter=    1 fnrm=     0.1568809262600437E-04 nfe=     10
#  iter=    2 fnrm=     0.5860474279570506E-09 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             2.724%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    200
#
#  iter=    0 fnrm=     0.3937443524123036E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.6897602618657838E-04 nfe=     10
#  iter=    2 fnrm=     0.1253330632078353E-07 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940313004148741E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             3.208%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    199
#
#  iter=    1 fnrm=     0.8145385801844806E-04 nfe=      9
#  iter=    2 fnrm=     0.1835748927346185E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940735067491443E-02 nfe=      1
#  iter=    1 fnrm=     0.8903439794905555E-04 nfe=      9
#  iter=    2 fnrm=     0.2369723325939673E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ncore_down/progress0p037.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             3.692%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    198
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940820738367571E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             4.176%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    197
#
#  iter=    1 fnrm=     0.9606902144413666E-04 nfe=      9
#  iter=    2 fnrm=     0.2956495736810835E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940869356896642E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             4.660%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    196
#
#  iter=    1 fnrm=     0.1034539415586550E-03 nfe=      9
#  iter=    2 fnrm=     0.3341861115338539E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940901983492745E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             5.144%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    195
#
#  iter=    1 fnrm=     0.1113131273195528E-03 nfe=      9
#  iter=    2 fnrm=     0.4534945663217013E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3940918231487789E-02 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             5.628%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    88
#
#  iter=    1 fnrm=     0.1203910766141531E-03 nfe=      9
#  iter=    2 fnrm=     0.5675135770665763E-07 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             6.693%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    87
#
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8747573924427906E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.6197240154491525E-03 nfe=     10
#  iter=    2 fnrm=     0.1530767441556568E-05 nfe=     18
#  iter=    3 fnrm=     0.2320208359638101E-10 nfe=     29
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8753854450197954E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             7.758%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    86
#
#  iter=    1 fnrm=     0.8395579948169374E-03 nfe=     10
#  iter=    2 fnrm=     0.3325493963190181E-05 nfe=     18
#  iter=    3 fnrm=     0.7295679362339534E-10 nfe=     28
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8754735387606422E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             8.822%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    85
#
#  iter=    1 fnrm=     0.1079753048630438E-02 nfe=     10
#  iter=    2 fnrm=     0.6988838560316735E-05 nfe=     18
#  iter=    3 fnrm=     0.2604891695872891E-09 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8754880595897843E-02 nfe=      1
#  iter=    1 fnrm=     0.1402396793120649E-02 nfe=     10
#  iter=    2 fnrm=     0.1424314455445824E-04 nfe=     18
#  iter=    3 fnrm=     0.1276363196993175E-08 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ncore_down/progress0p099.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             9.887%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    84
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8754949248213236E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             10.952%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    83
#
#  iter=    1 fnrm=     0.1902733065375279E-02 nfe=     10
#  iter=    2 fnrm=     0.3604714308445496E-04 nfe=     17
#  iter=    3 fnrm=     0.1148640157548151E-07 nfe=     25
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8754975501282965E-02 nfe=      1
#  iter=    1 fnrm=     0.2806997282391783E-02 nfe=     10
#  iter=    2 fnrm=     0.1277458619569761E-03 nfe=     18
#  iter=    3 fnrm=     0.2775228541965377E-06 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             12.017%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    82
#
#  Interpolants created; mype =                   -1
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Reading grid data from gridue.hdf5.hdf5
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8754971667747594E-02 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             13.082%
#     -Advancing by                         2.343%
#     -Steps to target at current delta:    37
#
#  iter=    1 fnrm=     0.4996225195047306E-02 nfe=     12
#  iter=    2 fnrm=     0.1131111343492525E-02 nfe=     18
#  iter=    3 fnrm=     0.1377465177783530E-03 nfe=     26
#  iter=    4 fnrm=     0.3273002839283569E-05 nfe=     36
#  iter=    5 fnrm=     0.2038472620170356E-08 nfe=     48
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#
# ===== FAIL 1/3 =====
# ===== DECREASE DELTA AND TRY AGAIN =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             13.082%
#     -Advancing by                         1.171%
#     -Steps to target at current delta:    74
#
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1967029460686746E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.8960144237127400E-01 nfe=     10
#  iter=    2 fnrm=     0.1578411225108383     nfe=     15
#  iter=    3 fnrm=     0.7031618037217738E-01 nfe=     19
#  iter=    4 fnrm=     0.5808242073919705E-01 nfe=     23
#  iter=    5 fnrm=     0.8312534416539861     nfe=     27
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#
# ===== FAIL 2/3 ===== iter=    0 fnrm=     0.9841928949517046E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.4806951458520661E-01 nfe=     10
#  iter=    2 fnrm=     0.8068465408948870E-01 nfe=     14
#  iter=    3 fnrm=     0.3495043481715444E-01 nfe=     18
#  iter=    4 fnrm=     0.3288879572408193E-01 nfe=     22
#  iter=    5 fnrm=     0.1532308964617780     nfe=     26
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
# ===== DECREASE DELTA AND TRY AGAIN =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             13.082%
#     -Advancing by                         0.586%
#     -Steps to target at current delta:    148
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
# ===== RECOVERY LOOP ENTERED =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             13.082%
#
#
# ===== STATIC ITERATION AT DTREAL=2.00e-04 =====
#  iter=    0 fnrm=     0.4934504466527403E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2208148334319245E-01 nfe=     11
#  iter=    2 fnrm=     0.2463824588724390E-01 nfe=     15
#  iter=    3 fnrm=     0.1485774740656737E-01 nfe=     19
#  iter=    4 fnrm=     0.9929973900970154     nfe=     24
#  iter=    5 fnrm=     0.1626702574691621     nfe=     27
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#
# ===== STATIC ITERATION AT DTREAL=1.00e-03 ===== iter=    0 fnrm=     0.4218103317449009E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.7910023077653745E-05 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Reading grid data from gridue.hdf5.hdf5
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4117343940527802E-03 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=5.00e-03 =====
#  iter=    1 fnrm=     0.1022153561414134E-03 nfe=     17
#  iter=    2 fnrm=     0.2188744707202296E-05 nfe=     26
#  iter=    3 fnrm=     0.1099232260174329E-08 nfe=     39
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3357167707748893E-03 nfe=      1
#
# ===== STATIC FNRM REDUCTION FAILED =====
#
# ===== ENTER TIME-DEPENDENT SOLVE =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             13.082%
#
#  iter=    1 fnrm=     0.6959859038748182E-03 nfe=     37
#  iter=    2 fnrm=     0.1125613213846409E-02 nfe=     47
#  iter=    3 fnrm=     0.6000893548865916E-03 nfe=     52
#  iter=    4 fnrm=     0.9029570498346193E-02 nfe=     59
#  iter=    5 fnrm=     0.1815108329895591E-02 nfe=     63
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1679334100626349E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5963392835801120E-04 nfe=      4
#  iter=    2 fnrm=     0.6740665708940720E-09 nfe=      8
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
#  Initial successful time-step exists
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-05 ***
# ---------------------------------------------------------------
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8223842322060781E-02 nfe=      1
#  iter=    1 fnrm=     0.1308999691884568E-04 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.6825489757835294E-02 nfe=      1
#  iter=    1 fnrm=     0.5418132519957500E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 1.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #2
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.5926012222145941E-02 nfe=      1
#  iter=    1 fnrm=     0.2529209621462791E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 2.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #3
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.5315428773026316E-02 nfe=      1
#  iter=    1 fnrm=     0.4495806780705948E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 3.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #4
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4895105263784053E-02 nfe=      1
#  iter=    1 fnrm=     0.1517195833352386E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 4.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #5
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4615681503915845E-02 nfe=      1
#  iter=    1 fnrm=     0.2432426792301802E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 5.0000E-05; Timestep = 1.0000E-05
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-05 ***
# ---------------------------------------------------------------
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4459540177646948E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.9861616001173122E-04 nfe=      5
#  iter=    2 fnrm=     0.2964539564723223E-05 nfe=     10
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4537337738668707E-02 nfe=      1
#  Total time = 6.0000E-05; Timestep = 3.4000E-05
#
# ** Fortran index of trouble making equation is:
# 1495
# ** Number of equations solved per cell:
#     numvar = 13
#
# ** Troublemaker equation is:
# Gas density equation of species 2: iv_t=13
#
# ** Troublemaker cell (ix,iy) is:
# [6 6]
#
# ** Timestep for troublemaker equation:
# 3.4000e-05
#
# ** yl for troublemaker equation:
# 7.1464e-07
#
# ** yldot*sfscal for troublemaker equation:
# 2.4949e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.13E-05 ***
# ---------------------------------------------------------------
# Solving for delta=15.082%
#  iter=    1 fnrm=     0.3404420798738856E-03 nfe=      5
#  iter=    2 fnrm=     0.2478841429243704E-03 nfe=     10
#  iter=    3 fnrm=     0.2401803864288575E-03 nfe=     17
#  iter=    4 fnrm=     0.2611831981787225E-03 nfe=     24
#  iter=    5 fnrm=     0.2269175763699320E-03 nfe=     29
#  iter=    6 fnrm=     0.2406765549808695E-03 nfe=     37
#  iter=    7 fnrm=     0.2584250746406889E-03 nfe=     44
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4537337738668707E-02 nfe=      1
#  iter=    1 fnrm=     0.2492402163725179E-04 nfe=      9
#  iter=    2 fnrm=     0.1192810718436322E-06 nfe=     22
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4713836912101571E-02 nfe=      1
#  iter=    1 fnrm=     0.4625833817723583E-04 nfe=      9
#  iter=    2 fnrm=     0.5979214647602396E-06 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 1.0533E-04; Timestep = 1.1333E-05
#
#  Inner iteration #2
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4950819478997915E-02 nfe=      1
#  iter=    1 fnrm=     0.1045922732006280E-03 nfe=     10
#  iter=    2 fnrm=     0.6787098058276109E-05 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p151_dtrun_last_ii2.hdf5
#  Total time = 1.1667E-04; Timestep = 1.1333E-05
#
#  Inner iteration #3
#
# Solving for delta=15.082%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.5249809473005716E-02 nfe=      1
#  Total time = 1.1667E-04; Timestep = 1.1333E-05
#
# ** Fortran index of trouble making equation is:
# 1495
# ** Number of equations solved per cell:
#     numvar = 13
#
# ** Troublemaker equation is:
# Gas density equation of species 2: iv_t=13
#
# ** Troublemaker cell (ix,iy) is:
# [6 6]
#
# ** Timestep for troublemaker equation:
# 1.1333e-05
#
# ** yl for troublemaker equation:
# 7.1949e-07
#
# ** yldot*sfscal for troublemaker equation:
# 5.0088e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.78E-06 ***
# ---------------------------------------------------------------
# Solving for delta=15.082%
#  iter=    1 fnrm=     0.5366495819608028E-03 nfe=     11
#  iter=    2 fnrm=     0.5572391011394405E-03 nfe=     27
#  iter=    3 fnrm=     0.5830495925823009E-03 nfe=     40
#  iter=    4 fnrm=     0.5428567336070629E-03 nfe=     53
#  iter=    5 fnrm=     0.5580909748963927E-03 nfe=     67
#  iter=    6 fnrm=     0.5890573921161179E-03 nfe=     80
#  iter=    7 fnrm=     0.5183228020900709E-03 nfe=     91
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.5249809473005716E-02 nfe=      1
#  iter=    1 fnrm=     0.2739209473109231E-04 nfe=     15
#  iter=    2 fnrm=     0.5808177298916241E-07 nfe=     41
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
# ...
#  iter=    1 fnrm=     0.4616321574975387E-08 nfe=     14
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 6.9623E-02; Timestep = 1.9842E-02
#
#  Inner iteration #2
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4426812173753454E-05 nfe=      1
#  iter=    1 fnrm=     0.6948671055040340E-09 nfe=     14
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 8.9465E-02; Timestep = 1.9842E-02
#
#  Inner iteration #3
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.2538098451228201E-05 nfe=      1
#  iter=    1 fnrm=     0.1674326520567264E-09 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 1.0931E-01; Timestep = 1.9842E-02
#
#  Inner iteration #4
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1495696619363519E-05 nfe=      1
#  iter=    1 fnrm=     0.6777908252013793E-10 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 1.2915E-01; Timestep = 1.9842E-02
#
#  Inner iteration #5
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8657326477744709E-06 nfe=      1
#  iter=    1 fnrm=     0.3116468120132901E-10 nfe=     16
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 1.4899E-01; Timestep = 1.9842E-02
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 14 New time-step: 6.75E-02 ***
# ----------------------------------------------------------------
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4903746840729695E-06 nfe=      1
#  iter=    1 fnrm=     0.2804144344648420E-10 nfe=     17
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1305605323444331E-06 nfe=      1
#  iter=    1 fnrm=     0.4043799192558580E-11 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 2.3630E-01; Timestep = 6.7463E-02
#
#  Inner iteration #2
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3386968810070449E-07 nfe=      1
#  iter=    1 fnrm=     0.8675088272371043E-12 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 3.0376E-01; Timestep = 6.7463E-02
#
#  Inner iteration #3
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.8641528632701758E-08 nfe=      1
#  iter=    1 fnrm=     0.3341179454652630E-12 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#  Total time = 3.7122E-01; Timestep = 6.7463E-02
#
#  Inner iteration #4
#
# Solving for delta=99.292%
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.2181657936379267E-08 nfe=      1
#  iter=    1 fnrm=     0.1470071849034185E-12 nfe=     20
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./ncore_down/progress0p993_dtrun_last_ii2.hdf5
#
# ******************************
# ** SUCCESS: fnrm < bbb.ftol **
# ******************************
# Total runtime: 0:00:28
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             99.506%
#     -Advancing by                         0.214%
#     -Steps to target at current delta:    2
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.4836683638079621E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.8016631966695857E-04 nfe=     10
#  iter=    2 fnrm=     0.8509378608304769E-08 nfe=     21
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             99.720%
#     -Advancing by                         0.214%
#     -Steps to target at current delta:    1
#
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.2423967925364712E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             99.935%
#     -Advancing by                         0.214%
#     -Steps to target at current delta:    0
#
#  iter=    1 fnrm=     0.2907811737395269E-04 nfe=     11
#  iter=    2 fnrm=     0.1312624593388630E-08 nfe=     22
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.7429276521547321E-03 nfe=      1
#
# ===== TARGET VALUE ACHIEVED: REDUCE FNORM ====
#     -Variable(s) being solved:
#                                         - ncore
#     -Progress                             100.000%
#
#
# ===== STATIC ITERATION AT DTREAL=2.00e-04 =====
#  iter=    1 fnrm=     0.4505696665121499E-05 nfe=     12
#  iter=    2 fnrm=     0.2698139753630074E-10 nfe=     25
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4534797834129423E-04 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=1.00e-03 =====
#  iter=    1 fnrm=     0.8836269510441368E-09 nfe=     34
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4435544709811433E-04 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=5.00e-03 =====
#  iter=    1 fnrm=     0.7680475220774806E-08 nfe=     20
#  iter=    2 fnrm=     0.1169324542523547E-09 nfe=     45
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.4186993952737715E-04 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=2.50e-02 =====
#  iter=    1 fnrm=     0.8185095706327811E-07 nfe=     14
#  iter=    2 fnrm=     0.1569841357157607E-08 nfe=     29
#  iter=    3 fnrm=     0.1867816611359172E-12 nfe=     47
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.3391555752679218E-04 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=1.25e-01 =====
#  iter=    1 fnrm=     0.1334271568673565E-06 nfe=     14
#  iter=    2 fnrm=     0.2182631872509754E-08 nfe=     29
#  iter=    3 fnrm=     0.2930945379498560E-12 nfe=     47
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.9898139233086399E-05 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=6.25e-01 =====
#  iter=    1 fnrm=     0.1323331298883312E-07 nfe=     16
#  iter=    2 fnrm=     0.2977695982409065E-09 nfe=     33
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.6915970491425729E-06 nfe=      1
#
# ===== STATIC ITERATION AT DTREAL=1.00e+20 =====
#  iter=    1 fnrm=     0.2213151911363676E-09 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#  Reading grid data from gridue.hdf5.hdf5
#  TARGET MATERIAL IS      GRAPHITE
#  BOMBARDING IONS ARE     D
#  Grid data read successfully:
#      file name:   gridue.hdf5.hdf5
#      run-ID:      EFITD    05/08/2002    #110465  3500ms
#  iter=    0 fnrm=     0.1674005902092895E-07 nfe=      1
#  iter=    1 fnrm=     0.4027905623665065E-11 nfe=     20
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ncore_down/progress1p000_staticiter.hdf5
# ===== CONVERGED AT STEADY STATE: RETURNING TO MAIN LOOP =====
# ++++++++++++++++++++++++++++++++++++++++
# +++++ CONTINUATION SOLVE SUCCEEDED +++++
# ++++++++++++++++++++++++++++++++++++++++
# Total runtime: 0:03:14
# Folder SUCCESS_ncore_down.hdf5 not found, saving output to cwd...
# Intermediate solution written to SUCCESS_ncore_down.hdf5

# %% [markdown]
# The continuation solver will create a directory, as discussed in Chapter 4, containing a set of steady-state solutions which can be utilized by UETOOLS Database objects, as discussed in Chapter 6.

# %%
# !ls ncore_down
# Out:
# progress0p001.hdf5                progress0p458.hdf5
# progress0p011.hdf5                progress0p880_dtrun_last_ii2.hdf5
# progress0p037.hdf5                progress0p896.hdf5
# progress0p099.hdf5                progress0p916_dtrun_last_ii2.hdf5
# progress0p151_dtrun_last_ii2.hdf5 progress0p947.hdf5
# progress0p180.hdf5                progress0p993_dtrun_last_ii2.hdf5
# progress0p262.hdf5                progress1p000_staticiter.hdf5

# %% [markdown]
# As a first step to recovering from several consequtive failed solver steps, the continuation solver will perform static iterations at the value of the last successful execution to bring down the initial fnrm. These iterations, if successful, are named \*\_staticiter.hdf5 to identify these well-converged steady-state solutions. In some situations, this static iteration scheme will fail. In such circumstances, the continuation solver calls the time-dependent solver to ensure convergence. Such runs are identified by \*\_dtrun_last_ii2.hdf5 appearing in the name. All of these saves are compatible with Database Objects, as discussed Chapter 6.
