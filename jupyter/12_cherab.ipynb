# %%
# Restore the case
from os import chdir
#chdir('testcase_hires')
from uetools import Case
c = Case('input.yaml')
# Out:
# UETOOLS-style save successfully restored from /home/dudson2/LDRD/UETOOLS/jupyter/testcase_hires/nc20.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 2.27e+00

# %% [markdown]
# # Experimental geometry
# Create a Cherab raytracing world modeling the DIII-D tokamak

# %%
experiment = c.cherab.d3d()

# %% [markdown]
# # Power emission
#
# Specify the power radiation in [W/m^3] in each cell. The first time this is done the UEDGE mesh will be triangulated.

# %%
experiment.set_emission(c.get('pradhyd'))
# Out:
# Triangulating the UEDGE grid

# %% [markdown]
# # Pinhole camera
#
# This models a simple broad spectrum pinhole camera.

# %%
experiment.camera.observe()
# Out:
# /tmp/ipykernel_105344/459034992.py:1: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use manager.set_window_title or GUI-specific methods instead.
#   experiment.camera.observe()
# Render time: 1.008s (17.38% complete, 25.4k rays)
# Render time: 2.013s (46.88% complete, 43.3k rays)
# Render time: 3.015s (73.57% complete, 39.0k rays)
# Render time: 4.022s (99.83% complete, 38.5k rays)
# Render complete - time elapsed 4.157s - 35.2k rays/s
